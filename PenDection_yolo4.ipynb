# %%
# %cd /content
# !rm penDetect
# !git clone https://github.com/nowage/penDetect
# !cd penDetect
# Out:
# /content
# rm: cannot remove 'penDetect': Is a directory
# fatal: destination path 'penDetect' already exists and is not an empty directory.

# %%
# !bash install.sh
